# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv('./Accident-filtered.csv')

# %%
df.head()
# Out:
#    S no. Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0      1         2.E+12               342200.0                  850290
# 1      2         2.E+12               529710.0                  277320
# 2      3         2.E+12               565170.0                  172960
# 3      4  200501YE80011               535230.0                  192430
# 4      5  200501RY10089               551510.0                  177770
#
#    Longitude   Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  -2.967122  57.539108            92                  3                   2
# 1  -0.095826  52.378530            35                  3                   1
# 2   0.374698  51.431513            46                  3                   1
# 3  -0.048247  51.614411             1                  3                   1
# 4   0.180406  51.478547             1                  3                   1
#
#    Number_of_Casualties  ... Pedestrian_Crossing-Physical_Facilities  \
# ...

# %%
df1=df.head(50000)

# %%
df1.shape
# Out:
# (50000, 33)

# %%
df1.columns
# Out:
# Index(['S no.', 'Accident_Index', 'Location_Easting_OSGR',
#        'Location_Northing_OSGR', 'Longitude', 'Latitude', 'Police_Force',
#        'Accident_Severity', 'Number_of_Vehicles', 'Number_of_Casualties',
#        'Date', 'Day_of_Week', 'Time', 'Local_Authority_(District)',
#        'Local_Authority_(Highway)', '1st_Road_Class', '1st_Road_Number',
#        'Road_Type', 'Speed_limit', 'Junction_Control', '2nd_Road_Class',
#        '2nd_Road_Number', 'Pedestrian_Crossing-Human_Control',
#        'Pedestrian_Crossing-Physical_Facilities', 'Light_Conditions',
#        'Weather_Conditions', 'Road_Surface_Conditions',
#        'Special_Conditions_at_Site', 'Carriageway_Hazards',
#        'Urban_or_Rural_Area', 'Did_Police_Officer_Attend_Scene_of_Accident',
#        'LSOA_of_Accident_Location', 'Year'],
#       dtype='object')

# %%
y=df['Accident_Index']

# %%
x=df.drop('logs', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11120\4035054743.py in <module>
# ----> 1 x=df.drop('logs', axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
# ...

# %%
x=df.drop('Accident_Index', axis=1)

# %%
df.head()
# Out:
#    S no. Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0      1         2.E+12               342200.0                  850290
# 1      2         2.E+12               529710.0                  277320
# 2      3         2.E+12               565170.0                  172960
# 3      4  200501YE80011               535230.0                  192430
# 4      5  200501RY10089               551510.0                  177770
#
#    Longitude   Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  -2.967122  57.539108            92                  3                   2
# 1  -0.095826  52.378530            35                  3                   1
# 2   0.374698  51.431513            46                  3                   1
# 3  -0.048247  51.614411             1                  3                   1
# 4   0.180406  51.478547             1                  3                   1
#
#    Number_of_Casualties  ... Pedestrian_Crossing-Physical_Facilities  \
# ...

# %%
data = {
    'A': ['Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR', 'Longitude', 'Latitude','Carriageway_Hazards','Urban_or_Rural_Area', 'Did_Police_Officer_Attend_Scene_of_Accident'],
    'B': ['Police_Force', 'Date', 'Day_of_Week', 'Time', 'Local_Authority_(District)','Light_Conditions', 'Junction_Control', '2nd_Road_Class'],
    'C': ['Local_Authority_(Highway)', '1st_Road_Class', '1st_Road_Number','Year', 'LSOA_of_Accident_Location','2nd_Road_Number','Pedestrian_Crossing-Physical_Facilities','S no.'],
    'D': ['Speed_limit', 'Road_Surface_Conditions', 'Weather_Conditions', 'Special_Conditions_at_Site', 'Road_Type','Number_of_Vehicles', 'Number_of_Casualties',  'Pedestrian_Crossing-Human_Control'],
    
df = pd.DataFrame(data)
  
df.drop(['A','C', 'B'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11120\2252454519.py in <module>
#       6     'E': ['Carriageway_Hazards','Urban_or_Rural_Area', 'Did_Police_Officer_Attend_Scene_of_Accident' 'Light_Conditions', 'Junction_Control', '2nd_Road_Class',
#       7        '2nd_Road_Number']}
# ----> 8 df = pd.DataFrame(data)
#       9
#      10 df.drop(['A','E','C', 'B'], axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     634         elif isinstance(data, dict):
#     635             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637         elif isinstance(data, ma.MaskedArray):
#     638             import numpy.ma.mrecords as mrecords
#
# ...

# %%
data = {
    'A': ['Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR', 'Longitude', 'Latitude','Carriageway_Hazards','Urban_or_Rural_Area', 'Did_Police_Officer_Attend_Scene_of_Accident'],
    'B': ['Police_Force', 'Date', 'Day_of_Week', 'Time', 'Local_Authority_(District)','Light_Conditions', 'Junction_Control', '2nd_Road_Class'],
    'C': ['Local_Authority_(Highway)', '1st_Road_Class', '1st_Road_Number','Year', 'LSOA_of_Accident_Location','2nd_Road_Number','Pedestrian_Crossing-Physical_Facilities','S no.'],
    'D': ['Speed_limit', 'Road_Surface_Conditions', 'Weather_Conditions', 'Special_Conditions_at_Site', 'Road_Type','Number_of_Vehicles', 'Number_of_Casualties',  'Pedestrian_Crossing-Human_Control'],
    
df1 = pd.DataFrame(data)
  
df1.drop(['A','C', 'B'], axis=1)
# Out:
#   File "C:\Users\sonis\AppData\Local\Temp\ipykernel_11120\320477312.py", line 7
#     df = pd.DataFrame(data)
#        ^
# SyntaxError: invalid syntax

# %%
data = {
    'A': ['Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR', 'Longitude', 'Latitude','Carriageway_Hazards','Urban_or_Rural_Area', 'Did_Police_Officer_Attend_Scene_of_Accident'],
    'B': ['Police_Force', 'Date', 'Day_of_Week', 'Time', 'Local_Authority_(District)','Light_Conditions', 'Junction_Control', '2nd_Road_Class'],
    'C': ['Local_Authority_(Highway)', '1st_Road_Class', '1st_Road_Number','Year', 'LSOA_of_Accident_Location','2nd_Road_Number','Pedestrian_Crossing-Physical_Facilities','S no.'],
    'D': ['Speed_limit', 'Road_Surface_Conditions', 'Weather_Conditions', 'Special_Conditions_at_Site', 'Road_Type','Number_of_Vehicles', 'Number_of_Casualties',  'Pedestrian_Crossing-Human_Control']}
    
df1 = pd.DataFrame(data)
  
df1.drop(['A','C', 'B'], axis=1)
# Out:
#   File "C:\Users\sonis\AppData\Local\Temp\ipykernel_11120\2155467969.py", line 7
#     df1 = pd.DataFrame(data)
#         ^
# SyntaxError: invalid syntax

# %%
data = {
    'A': ['Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR', 'Longitude', 'Latitude','Carriageway_Hazards','Urban_or_Rural_Area', 'Did_Police_Officer_Attend_Scene_of_Accident'],
    'B': ['Police_Force', 'Date', 'Day_of_Week', 'Time', 'Local_Authority_(District)','Light_Conditions', 'Junction_Control', '2nd_Road_Class'],
    'C': ['Local_Authority_(Highway)', '1st_Road_Class', '1st_Road_Number','Year', 'LSOA_of_Accident_Location','2nd_Road_Number','Pedestrian_Crossing-Physical_Facilities','S no.'],
    'D': ['Speed_limit', 'Road_Surface_Conditions', 'Weather_Conditions', 'Special_Conditions_at_Site', 'Road_Type','Number_of_Vehicles', 'Number_of_Casualties',  'Pedestrian_Crossing-Human_Control']}
    
df1 = pd.DataFrame(data)
  
df1.drop(['A','C', 'B'], axis=0)
# Out:
#                                    D
# 0                        Speed_limit
# 1            Road_Surface_Conditions
# 2                 Weather_Conditions
# 3         Special_Conditions_at_Site
# 4                          Road_Type
# 5                 Number_of_Vehicles
# 6               Number_of_Casualties
# 7  Pedestrian_Crossing-Human_Control

# %%
data = {
    'A': ['Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR', 'Longitude', 'Latitude','Carriageway_Hazards','Urban_or_Rural_Area', 'Did_Police_Officer_Attend_Scene_of_Accident'],
    'B': ['Police_Force', 'Date', 'Day_of_Week', 'Time', 'Local_Authority_(District)','Light_Conditions', 'Junction_Control', '2nd_Road_Class'],
    'C': ['Local_Authority_(Highway)', '1st_Road_Class', '1st_Road_Number','Year', 'LSOA_of_Accident_Location','2nd_Road_Number','Pedestrian_Crossing-Physical_Facilities','S no.'],
    'D': ['Speed_limit', 'Road_Surface_Conditions', 'Weather_Conditions', 'Special_Conditions_at_Site', 'Road_Type','Number_of_Vehicles', 'Number_of_Casualties',  'Pedestrian_Crossing-Human_Control']}
    
df1 = pd.DataFrame(data)
  
df1.drop(['A','C', 'B'], axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11120\2815695489.py in <module>
#       7 df1 = pd.DataFrame(data)
#       8
# ----> 9 df1.drop(['A','C', 'B'], axis=0)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df1.head()
# Out:
#                         A                           B  \
# 0          Accident_Index                Police_Force
# 1   Location_Easting_OSGR                        Date
# 2  Location_Northing_OSGR                 Day_of_Week
# 3               Longitude                        Time
# 4                Latitude  Local_Authority_(District)
#
#                            C                           D
# 0  Local_Authority_(Highway)                 Speed_limit
# 1             1st_Road_Class     Road_Surface_Conditions
# 2            1st_Road_Number          Weather_Conditions
# 3                       Year  Special_Conditions_at_Site
# 4  LSOA_of_Accident_Location                   Road_Type

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('./Accident-filtered.csv')
df.head()
df1=df.head(50000)
df1.columns
# Out:
# Index(['S no.', 'Accident_Index', 'Location_Easting_OSGR',
#        'Location_Northing_OSGR', 'Longitude', 'Latitude', 'Police_Force',
#        'Accident_Severity', 'Number_of_Vehicles', 'Number_of_Casualties',
#        'Date', 'Day_of_Week', 'Time', 'Local_Authority_(District)',
#        'Local_Authority_(Highway)', '1st_Road_Class', '1st_Road_Number',
#        'Road_Type', 'Speed_limit', 'Junction_Control', '2nd_Road_Class',
#        '2nd_Road_Number', 'Pedestrian_Crossing-Human_Control',
#        'Pedestrian_Crossing-Physical_Facilities', 'Light_Conditions',
#        'Weather_Conditions', 'Road_Surface_Conditions',
#        'Special_Conditions_at_Site', 'Carriageway_Hazards',
#        'Urban_or_Rural_Area', 'Did_Police_Officer_Attend_Scene_of_Accident',
#        'LSOA_of_Accident_Location', 'Year'],
#       dtype='object')

# %%
df.head()
# Out:
#    S no. Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0      1         2.E+12               342200.0                  850290
# 1      2         2.E+12               529710.0                  277320
# 2      3         2.E+12               565170.0                  172960
# 3      4  200501YE80011               535230.0                  192430
# 4      5  200501RY10089               551510.0                  177770
#
#    Longitude   Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  -2.967122  57.539108            92                  3                   2
# 1  -0.095826  52.378530            35                  3                   1
# 2   0.374698  51.431513            46                  3                   1
# 3  -0.048247  51.614411             1                  3                   1
# 4   0.180406  51.478547             1                  3                   1
#
#    Number_of_Casualties  ... Pedestrian_Crossing-Physical_Facilities  \
# ...

# %%
y=df['S no.', 'Accident_Index', 'Location_Easting_OSGR',
       'Location_Northing_OSGR', 'Longitude', 'Latitude', 'Police_Force']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('S no.', 'Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR', 'Longitude', 'Latitude', 'Police_Force')
#
# ...

# %%
y=df['Year']

# %%
x = df.drop('Year', axis =1)

# %%
df.head()
# Out:
#    S no. Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0      1         2.E+12               342200.0                  850290
# 1      2         2.E+12               529710.0                  277320
# 2      3         2.E+12               565170.0                  172960
# 3      4  200501YE80011               535230.0                  192430
# 4      5  200501RY10089               551510.0                  177770
#
#    Longitude   Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  -2.967122  57.539108            92                  3                   2
# 1  -0.095826  52.378530            35                  3                   1
# 2   0.374698  51.431513            46                  3                   1
# 3  -0.048247  51.614411             1                  3                   1
# 4   0.180406  51.478547             1                  3                   1
#
#    Number_of_Casualties  ... Pedestrian_Crossing-Physical_Facilities  \
# ...

# %%
x = df.drop('Year', axis =1)

# %%
x.head()
# Out:
#    S no. Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0      1         2.E+12               342200.0                  850290
# 1      2         2.E+12               529710.0                  277320
# 2      3         2.E+12               565170.0                  172960
# 3      4  200501YE80011               535230.0                  192430
# 4      5  200501RY10089               551510.0                  177770
#
#    Longitude   Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  -2.967122  57.539108            92                  3                   2
# 1  -0.095826  52.378530            35                  3                   1
# 2   0.374698  51.431513            46                  3                   1
# 3  -0.048247  51.614411             1                  3                   1
# 4   0.180406  51.478547             1                  3                   1
#
#    Number_of_Casualties  ... Pedestrian_Crossing-Human_Control  \
# ...

# %%
a=df['S no.', 'Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR', 'Longitude', 'Latitude', 'Police_Force']
b = df.drop('S no.', 'Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR', 'Longitude', 'Latitude', 'Police_Force', axis =1)
b.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('S no.', 'Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR', 'Longitude', 'Latitude', 'Police_Force')
#
# ...

# %%
a=x['S no.', 'Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR', 'Longitude', 'Latitude', 'Police_Force']
b = a.drop('S no.', 'Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR', 'Longitude', 'Latitude', 'Police_Force', axis =1)
b.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('S no.', 'Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR', 'Longitude', 'Latitude', 'Police_Force')
#
# ...

# %%
a=x['S no.', 'Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR', 'Longitude', 'Latitude', 'Police_Force']
b = a.drop(['S no.', 'Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR', 'Longitude', 'Latitude', 'Police_Force'], axis =1)
b.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('S no.', 'Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR', 'Longitude', 'Latitude', 'Police_Force')
#
# ...

# %%
a=x['S no.', 'Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR', 'Longitude', 'Latitude', 'Police_Force']
b = a.drop(['S no.', 'Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR', 'Longitude', 'Latitude', 'Police_Force'], axis =1)
b.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('S no.', 'Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR', 'Longitude', 'Latitude', 'Police_Force')
#
# ...

# %%
x.drop(df.columns[[S no., Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force]], axis=1, inplace=True)
# Out:
# C:\Users\sonis\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5069: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = getitem(key)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38900\1084511712.py in <module>
# ----> 1 x.drop(df.columns[['S no.', 'Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR', 'Longitude', 'Latitude', 'Police_Force']], axis=1, inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    5067             key = np.asarray(key, dtype=bool)
#    5068
# -> 5069         result = getitem(key)
# ...

# %%
x.drop(x.columns[[S no., Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force]], axis=1, inplace=True)
# Out:
#   File "C:\Users\sonis\AppData\Local\Temp\ipykernel_38900\3376574302.py", line 1
#     x.drop(x.columns[[S no., Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force]], axis=1, inplace=True)
#                         ^
# SyntaxError: invalid syntax

# %%
x.drop(['Date', '1st_Road_Class', '1st_Road_Number', 'Pedestrian_Crossing-Physical_Facilities', 'Light_Conditions', 'Carriageway_Hazards', 'Did_Police_Officer_Attend_Scene_of_Accident','LSOA_of_Accident_Location'], axis = 1, inplace = True)

# %%
x.head()
# Out:
#    Accident_Severity  Number_of_Vehicles  Number_of_Casualties        Date  \
# 0                  3                   2                     1  01-01-2005
# 1                  3                   1                     1  01-01-2005
# 2                  3                   1                     1  01-01-2005
# 3                  3                   1                     1  01-01-2005
# 4                  3                   1                     1  01-01-2005
#
#    Day_of_Week         Time  Local_Authority_(District)  \
# 0            7  12:01:00 AM                         930
# 1            7  12:05:00 AM                         393
# 2            7  12:10:00 AM                         535
# 3            7  12:15:00 AM                          32
# 4            7  12:16:00 AM                          18
#
#   Local_Authority_(Highway)  1st_Road_Class  1st_Road_Number  ...  \
# 0                 S12000020               4             9014  ...
# ...

# %%
x.columns
# Out:
# Index(['Accident_Severity', 'Number_of_Vehicles', 'Number_of_Casualties',
#        'Day_of_Week', 'Time', 'Local_Authority_(District)',
#        'Local_Authority_(Highway)', 'Road_Type', 'Speed_limit',
#        'Junction_Control', '2nd_Road_Class', '2nd_Road_Number',
#        'Pedestrian_Crossing-Human_Control', 'Weather_Conditions',
#        'Road_Surface_Conditions', 'Special_Conditions_at_Site',
#        'Urban_or_Rural_Area'],
#       dtype='object')

# %%
x.drop(['Urban_or_Rural_Area', '2nd_Road_Number', '2nd_Road_Class', 'Junction_Control', 'Day_of_Week', 'Time',  'Local_Authority_(District)',
       'Local_Authority_(Highway)'], axis = 1, inplace = True)

# %%
x.head()
# Out:
#    Accident_Severity  Number_of_Vehicles  Number_of_Casualties  \
# 0                  3                   2                     1
# 1                  3                   1                     1
# 2                  3                   1                     1
# 3                  3                   1                     1
# 4                  3                   1                     1
#
#             Road_Type  Speed_limit Pedestrian_Crossing-Human_Control  \
# 0  Single carriageway           30             None within 50 metres
# 1  Single carriageway           60             None within 50 metres
# 2          Roundabout           30             None within 50 metres
# 3  Single carriageway           40             None within 50 metres
# 4  Single carriageway           30             None within 50 metres
#
#         Weather_Conditions Road_Surface_Conditions Special_Conditions_at_Site
# 0  Snowing with high winds                    Snow                       None
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=1000)

# %%
x_train
# Out:
#         Accident_Severity  Number_of_Vehicles  Number_of_Casualties  \
# 149666                  3                   2                     1
# 199608                  3                   2                     1
# 393574                  3                   3                     1
# 931962                  3                   2                     1
# 373368                  3                   2                     1
# ...                   ...                 ...                   ...
# 376059                  3                   2                     1
# 134848                  2                   2                     1
# 71751                   3                   2                     1
# 856663                  3                   2                     1
# 107955                  3                   3                     2
#
#                  Road_Type  Speed_limit Pedestrian_Crossing-Human_Control  \
# 149666  Single carriageway           30             None within 50 metres
# ...

# %%
X=x.head(50000)

# %%
X.head()
# Out:
#    Accident_Severity  Number_of_Vehicles  Number_of_Casualties  \
# 0                  3                   2                     1
# 1                  3                   1                     1
# 2                  3                   1                     1
# 3                  3                   1                     1
# 4                  3                   1                     1
#
#             Road_Type  Speed_limit Pedestrian_Crossing-Human_Control  \
# 0  Single carriageway           30             None within 50 metres
# 1  Single carriageway           60             None within 50 metres
# 2          Roundabout           30             None within 50 metres
# 3  Single carriageway           40             None within 50 metres
# 4  Single carriageway           30             None within 50 metres
#
#         Weather_Conditions Road_Surface_Conditions Special_Conditions_at_Site
# 0  Snowing with high winds                    Snow                       None
# ...

# %%
X.shape
# Out:
# (50000, 9)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38900\4061005578.py in <module>
# ----> 1 X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.1,random_state=1000)
#
# NameError: name 'Y' is not defined

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=1000)

# %%
x_train
# Out:
#         Accident_Severity  Number_of_Vehicles  Number_of_Casualties  \
# 149666                  3                   2                     1
# 199608                  3                   2                     1
# 393574                  3                   3                     1
# 931962                  3                   2                     1
# 373368                  3                   2                     1
# ...                   ...                 ...                   ...
# 376059                  3                   2                     1
# 134848                  2                   2                     1
# 71751                   3                   2                     1
# 856663                  3                   2                     1
# 107955                  3                   3                     2
#
#                  Road_Type  Speed_limit Pedestrian_Crossing-Human_Control  \
# 149666  Single carriageway           30             None within 50 metres
# ...

# %%
x.test
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38900\3344948863.py in <module>
# ----> 1 x.test
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'test'

# %%
x_test
# Out:
#          Accident_Severity  Number_of_Vehicles  Number_of_Casualties  \
# 913103                   3                   2                     1
# 651182                   3                   2                     1
# 169298                   3                   2                     1
# 300303                   3                   2                     1
# 215709                   3                   2                     2
# ...                    ...                 ...                   ...
# 1011226                  3                   2                     1
# 869986                   3                   1                     1
# 1005086                  3                   2                     1
# 692054                   2                   1                     1
# 256899                   3                   1                     1
#
#                   Road_Type  Speed_limit Pedestrian_Crossing-Human_Control  \
# ...

# %%
y_test
# Out:
# 913103     2011
# 651182     2009
# 169298     2005
# 300303     2006
# 215709     2006
#            ...
# 1011226    2011
# 869986     2010
# 1005086    2011
# 692054     2009
# 256899     2006
# Name: Year, Length: 104858, dtype: int64

# %%
X.to_csv('Dataset_Model.csv')
